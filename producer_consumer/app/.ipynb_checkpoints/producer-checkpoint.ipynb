# %%
import datetime
import json
import schedule
import requests as reqs

def myconverter(o):
    if isinstance(o, datetime.datetime):
        return o.__str__()
    
def num_calls():
    call = True
    i = 0
    while call:
        i += 1
        yield i
        
msg_num = num_calls()
##The producer of the requests
def producer(msg_num):
    url = "http://0.0.0.0:5000//consumer"
    headers = {'content-type': 'application/json'}
    for i in range(0, 10):
        start = datetime.datetime.now()
        data = { "msg_num": next(msg_num), "start" : start}
        result = reqs.post(url, data=json.dumps(data, default = myconverter), headers=headers)
        print(result.json()["message"])
    

schedule.every(1).seconds.do(producer, msg_num)
while True:
   schedule.run_pending()
# Out:
# The request was completed, job id: f3137210-8604-4611-b15f-3e04ca642665
# The request was completed, job id: 314dc66c-56c3-41ad-aa44-495753b1786b
# The request was completed, job id: 82676f73-bbd9-4904-ac80-6d026b70d532
# The request was completed, job id: dfde0252-1908-4977-a147-4414d7ce8b55
# The request was completed, job id: 02aae350-ebfc-4f06-a06c-73daa4db394c
# The request was completed, job id: 7bc8ce2f-adfa-4790-b106-a5822b85c29b
# The request was completed, job id: 9567ea1e-f7f3-47f6-a443-363208bf0142
# The request was completed, job id: a20ec38f-4175-415f-8645-373d85866f8b
# The request was completed, job id: e4bca26e-c9d9-42f4-a2eb-46962aefff9e
# The request was completed, job id: 97754c31-006b-4961-8f6b-ad92b5a72ce1
# The request was completed, job id: 3ab2f0d6-02c3-4431-96bf-1d890b148f2d
# The request was completed, job id: 13acefd0-e6e2-4390-aefe-c8f5cb087628
# The request was completed, job id: e0c1f197-5fee-4bc2-889e-9105a2b0a066
# The request was completed, job id: 2f5e1981-d9ac-4083-875d-fd1469efa22a
# The request was completed, job id: 1bcd5214-904e-4999-9c25-4dfc22fce127
# The request was completed, job id: 9e5a41c1-7a8f-4feb-9985-5a3b04e440df
# The request was completed, job id: d7e65aef-0eb6-4e1a-9a7a-90128d632560
# The request was completed, job id: b813779b-ca27-46c0-a870-d3aedb230c7f
# The request was completed, job id: 21e7bb04-d61e-4a4c-bf7e-21569a64bd6a
# The request was completed, job id: 1cd8d11e-7f72-4eec-b6a4-aa1e92d04b03
# The request was completed, job id: 915b4410-d740-4c81-9de6-171c293e2d55
# The request was completed, job id: 56a7cb0b-d12e-42c7-a278-3693ed0d2759
# The request was completed, job id: 9c85822d-3721-4d41-8868-d5a400f342cb
# The request was completed, job id: 72c0e277-0309-435f-a8eb-8eb7c68f4da3
# The request was completed, job id: 83d89358-a755-4a6b-84be-51dff2706dae
# The request was completed, job id: 6d36ae84-1747-4ec1-a13b-d5872a1cf65d
# The request was completed, job id: a043aa46-b212-41f1-9751-c8c5b627d3fd
# The request was completed, job id: 212bff25-c171-466c-8722-6ed7b14ad66c
# The request was completed, job id: 44158958-f12c-4fdc-ac45-5d782ac31492
# The request was completed, job id: 35b4deb2-cddc-4e9a-b3bd-79fa8a2a9315
# The request was completed, job id: 668406c3-4f5d-4540-b651-6d34a4d5d564
# The request was completed, job id: 1821711f-e934-478b-a95a-29d3999fc5bf
# The request was completed, job id: 18c8c1fd-0c98-475a-9d03-e1fced52b34a
# The request was completed, job id: 935142eb-26ed-4223-84df-d7e2f0210a82
# The request was completed, job id: d8e4e1de-83a2-40b6-a9b4-8d9467fd0775
# The request was completed, job id: 3637f06e-41d6-4d38-8c83-0f53c6f3efd5
# The request was completed, job id: 76003202-c598-4b84-966e-aa8c093a5aae
# The request was completed, job id: 68e80f48-a534-4a3b-979b-1aa14fc331df
# The request was completed, job id: 452d4f19-ca84-4158-ac96-66bd0dc04428
# The request was completed, job id: 00d66085-b708-46d1-b778-25d4719dcf86
# The request was completed, job id: a5043490-f208-4296-8e19-9bc7982f3686
# The request was completed, job id: 3f39babf-5b85-46ab-93dd-19bc91cbf2b8
# The request was completed, job id: 6ed0624b-7043-4634-9487-a9fa7197c843
# The request was completed, job id: 909e5032-8156-4ed0-8b81-31e579d27f4b
# The request was completed, job id: 379eea8e-99b0-4032-a396-f422524934e7
# The request was completed, job id: 9e0213f2-9f27-4995-b419-d7d0cc4876e1
# The request was completed, job id: 7dd6a158-0cc1-4c63-9e71-64d6f46996cd
# The request was completed, job id: 0d3a304d-7aeb-4030-b933-57b5575af2b8
# The request was completed, job id: ca23d106-38d1-4dd8-81f9-c53f64218c93
# The request was completed, job id: 7766d26d-373a-42f9-80e3-8c812ae2f8a7
# The request was completed, job id: 5b14b9a2-202e-4cde-a999-bc0300f83ffa
# The request was completed, job id: 091f09c6-e497-4551-a7b9-ec78ae89d8cb
# The request was completed, job id: c7ef7e50-7524-4100-a1ce-c15c4e395f51
# The request was completed, job id: a777e68a-d03e-40c4-af14-9adf265999b5
# The request was completed, job id: ae4f2148-b7d8-4de3-a731-dc132d4a379e
# The request was completed, job id: c5d854ca-6651-4eec-bc32-831aa120f654
# The request was completed, job id: 264c2f80-0bb0-4d54-8d7c-2a3df302fb6a
# The request was completed, job id: 98afb826-952c-4c8c-a208-0391de5fbded
# The request was completed, job id: 1ee195f5-e689-49d4-863e-abaf4151dab9
# The request was completed, job id: 2869884d-ec0f-4716-980b-d5fb8ca65a61
# The request was completed, job id: 509e8b1d-116b-4a80-b533-0c0f26abcb70
# The request was completed, job id: c5165ce0-33aa-4eb3-ab74-a8ffab345b81
# The request was completed, job id: 2bf17238-f22b-4486-900c-0487f91ddbe3
# The request was completed, job id: 01f0b55c-7037-406b-aac7-81c43f996176
# The request was completed, job id: 83f34a05-3421-42c4-ba96-126f3f4aca48
# The request was completed, job id: 35c5b0f9-7685-4cff-ada3-e148d17d9e24
# The request was completed, job id: 20dc5813-792b-4f79-bd6d-d28541c19425
# The request was completed, job id: 32e0898f-1fbd-40a3-aadd-ddf0e6dbe5ac
# The request was completed, job id: 40755f79-c8c0-45e9-9c98-9223862ff3ea
# The request was completed, job id: d24daf1f-540d-4899-892c-20ba3af41477
# The request was completed, job id: 00cc1ff3-f2ed-4593-9ad9-931726120bbe
# The request was completed, job id: 99b29430-52f9-40e3-94e2-dbbac8ff3638
# The request was completed, job id: 5c03e6df-fb29-4a79-bb1f-50c454212154
# The request was completed, job id: 42089e88-352d-43ec-854a-b2242cc57ff1
# The request was completed, job id: 75fc470d-04e5-4704-8f2e-6ce24023eecc
# The request was completed, job id: 6f97a2d1-bb76-415e-ae12-3999e805536b
# The request was completed, job id: f819ed12-78e4-47b7-abe5-e9fa69b26c46
# The request was completed, job id: 7be119f4-0b92-4924-9fd2-996d376ff9db
# The request was completed, job id: 8be24f05-22fa-483d-8a8b-f7b5bc581c48
# The request was completed, job id: 5927a0d7-fc18-44c2-9d78-43862327ea72
# The request was completed, job id: 189f0192-906d-4736-8469-bff4b1104ec8
# The request was completed, job id: 45132879-0409-4e0e-a3ea-44d197ed0e15
# The request was completed, job id: 611e3da1-dd1a-4315-a335-b842cab19696
# The request was completed, job id: e7de9c11-ca2a-4574-b7d6-3607f9b035a7
# The request was completed, job id: 58a5f80a-659d-42ab-a3de-837f24d24887
# The request was completed, job id: 596f4d66-b9ed-4469-a874-5167576e3451
# The request was completed, job id: aa8408dc-1248-4700-bead-53e11ed6eacd
# The request was completed, job id: a4def0e9-d3d0-4015-86ae-621830be3b14
# The request was completed, job id: 28dcc8f0-a298-453f-8bac-cfa315202ec7
# The request was completed, job id: e2823e37-0b72-4495-bfd1-06d8804c9c5a
# -----------------------------------------------------------------------
# KeyboardInterrupt                     Traceback (most recent call last)
# <ipython-input-9-01256dc6f127> in <module>
#      29 schedule.every(1).seconds.do(producer, msg_num)
#      30 while True:
# ---> 31    schedule.run_pending()
#      32
#
# /usr/local/lib/python3.8/site-packages/schedule/__init__.py in run_pending()
#     561     :data:`default scheduler instance <default_scheduler>`.
#     562     """
# --> 563     default_scheduler.run_pending()
#     564
#     565
#
# /usr/local/lib/python3.8/site-packages/schedule/__init__.py in run_pending(self)
#      92         runnable_jobs = (job for job in self.jobs if job.should_run)
#      93         for job in sorted(runnable_jobs):
# ---> 94             self._run_job(job)
#      95
#      96     def run_all(self, delay_seconds=0):
#
# /usr/local/lib/python3.8/site-packages/schedule/__init__.py in _run_job(self, job)
#     145
#     146     def _run_job(self, job):
# --> 147         ret = job.run()
#     148         if isinstance(ret, CancelJob) or ret is CancelJob:
#     149             self.cancel_job(job)
#
# /usr/local/lib/python3.8/site-packages/schedule/__init__.py in run(self)
#     464         """
#     465         logger.info('Running job %s', self)
# --> 466         ret = self.job_func()
#     467         self.last_run = datetime.datetime.now()
#     468         self._schedule_next_run()
#
# <ipython-input-2-01256dc6f127> in producer(msg_num)
#      23         start = datetime.datetime.now()
#      24         data = { "msg_num": next(msg_num), "start" : start}
# ---> 25         result = reqs.post(url, data=json.dumps(data, default = myconverter), headers=headers)
#      26         print(result.json()["message"])
#      27
#
# /usr/local/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# /usr/local/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     518         proxies = proxies or {}
#     519
# --> 520         settings = self.merge_environment_settings(
#     521             prep.url, proxies, stream, verify, cert
#     522         )
#
# /usr/local/lib/python3.8/site-packages/requests/sessions.py in merge_environment_settings(self, url, proxies, stream, verify, cert)
#     697             # Set environment's proxies.
#     698             no_proxy = proxies.get('no_proxy') if proxies is not None else None
# --> 699             env_proxies = get_environ_proxies(url, no_proxy=no_proxy)
#     700             for (k, v) in env_proxies.items():
#     701                 proxies.setdefault(k, v)
#
# /usr/local/lib/python3.8/site-packages/requests/utils.py in get_environ_proxies(url, no_proxy)
#     764     :rtype: dict
#     765     """
# --> 766     if should_bypass_proxies(url, no_proxy=no_proxy):
#     767         return {}
#     768     else:
#
# /usr/local/lib/python3.8/site-packages/requests/utils.py in should_bypass_proxies(url, no_proxy)
#     748         # parsed.hostname can be `None` in cases such as a file URI.
#     749         try:
# --> 750             bypass = proxy_bypass(parsed.hostname)
#     751         except (TypeError, socket.gaierror):
#     752             bypass = False
#
# /usr/local/Cellar/python@3.8/3.8.6/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in proxy_bypass(host)
#    2644             return proxy_bypass_environment(host, proxies)
#    2645         else:
# -> 2646             return proxy_bypass_macosx_sysconf(host)
#    2647
#    2648     def getproxies():
#
# /usr/local/Cellar/python@3.8/3.8.6/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in proxy_bypass_macosx_sysconf(host)
#    2621     def proxy_bypass_macosx_sysconf(host):
#    2622         proxy_settings = _get_proxy_settings()
# -> 2623         return _proxy_bypass_macosx_sysconf(host, proxy_settings)
#    2624
#    2625     def getproxies_macosx_sysconf():
#
# /usr/local/Cellar/python@3.8/3.8.6/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in _proxy_bypass_macosx_sysconf(host, proxy_settings)
#    2594             if hostIP is None:
#    2595                 try:
# -> 2596                     hostIP = socket.gethostbyname(hostonly)
#    2597                     hostIP = ip2num(hostIP)
#    2598                 except OSError:
#
# KeyboardInterrupt:
